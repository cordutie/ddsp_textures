# %%
import sys
import os

# Add the parent directory to the Python path
parent_dir = os.path.abspath('../..')
if parent_dir not in sys.path:
    sys.path.append(parent_dir)
    
# import modules
import ddsp_textures.training.wrapper

# %%
# Testing the trainer
json_path = '../auxiliar/example_configurations.json'

# Run the training
ddsp_textures.training.wrapper.train(json_path)
# Out:
# Model Parameters:
#
# audio_path: ../sounds/fire_short.wav
# frame_size: 32768
# hop_size: 16384
# sampling_rate: 44100
# features_annotator: <function features_freqavg_rate at 0x748130b4de10>
# batch_features_annotator: <function batch_features_freqavg_rate at 0x748130b4df30>
# freq_avg_level: 4
# hidden_size: 512
# deepness: 3
# param_per_env: 512
# N_filter_bank: 16
# architecture: <class 'ddsp_textures.architectures.DDSP.DDSP_TextEnv'>
# onset_detection_model_path: none
# loss_function: <function batch_statistics_loss at 0x748130b4e5f0>
# regularization: True
# batch_size: 16
# epochs: 3
# directory: ../trained_models
# model id: model_09
# /home/esteban/.local/lib/python3.10/site-packages/torch/cuda/__init__.py:118: UserWarning: CUDA initialization: The NVIDIA driver on your system is too old (found version 11040). Please update your GPU driver by downloading and installing a new version from the URL: http://www.nvidia.com/Download/index.aspx Alternatively, go to: https://pytorch.org to install a PyTorch version that has been compiled with your version of the CUDA driver. (Triggered internally at ../c10/cuda/CUDAFunctions.cpp:108.)
#   return torch._C._cuda_getDeviceCount() > 0
# Audio loaded from  ../sounds/fire_short.wav
# Final dataset size will be:  51
# Computing dataset
# ...
# Dataset computed!
# Training starting!
# Epoch 1/3: 100%|██████████| 4/4 [00:39<00:00,  9.82s/it]
# Epoch [1/3], Loss: 25.1675, Main Loss: 20.9449, Regularizer: 4.2225
# Epoch 2/3: 100%|██████████| 4/4 [00:36<00:00,  9.01s/it]
# Epoch [2/3], Loss: 26.3116, Main Loss: 21.6071, Regularizer: 4.7045
# Epoch 3/3: 100%|██████████| 4/4 [00:34<00:00,  8.63s/it]
# Epoch [3/3], Loss: 24.5106, Main Loss: 20.0094, Regularizer: 4.5012
# Training complete.
