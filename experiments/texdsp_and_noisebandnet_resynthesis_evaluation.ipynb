# %%
# !git clone https://github.com/cordutie/texstat.git
# !git clone https://github.com/gudgud96/frechet-audio-distance.git
# pip install -r frechet-audio-distance/requirements.txt
## rename the folder frechet-audio-distance to fad_repo
# mv frechet-audio-distance fad_repo

# %% [markdown]
# # FAD Resynthesis Scores

# %%
import sys
import os
import shutil
from texstat.fad import FAD_wrapper
from fad_repo.frechet_audio_distance.fad import FrechetAudioDistance

# Add the parent directory to the Python path
parent_dir = os.path.abspath('texstat/')
if parent_dir not in sys.path:
    sys.path.append(parent_dir)

# Pairs of paths to be compared
texture_types = ["bubbles", "fire", "keyboard", "rain", "river", "shards", "waterfall", "wind"]

pairs_texDSP = {}
for texture_type in texture_types:
    original_path = "evaluation_sounds_texDSP/"+texture_type+".wav"
    # make list of all files in evaluation_sounds/ that start with texture_type
    reproductions = ["evaluation_sounds_texDSP/"+reproduction for reproduction in os.listdir("evaluation_sounds_texDSP/") if reproduction.startswith(texture_type)]
    # list of pairs [original_path, reproduction_path]
    pairs_texDSP[texture_type] = []
    for reproduction in reproductions:
        if reproduction != original_path:
            pairs_texDSP[texture_type].append([original_path, reproduction])
    # sort
    pairs_texDSP[texture_type].sort(key=lambda x: x[1])

print(pairs_texDSP)

pairs_noisebandnet = {}
for texture_type in texture_types:
    original_path = "evaluation_sounds_noisebandnet/"+texture_type+".wav"
    # make list of all files in evaluation_sounds/ that start with texture_type
    reproductions = ["evaluation_sounds_noisebandnet/"+reproduction for reproduction in os.listdir("evaluation_sounds_noisebandnet/") if reproduction.startswith(texture_type)]
    # list of pairs [original_path, reproduction_path]
    pairs_noisebandnet[texture_type] = []
    for reproduction in reproductions:
        if reproduction != original_path:
            pairs_noisebandnet[texture_type].append([original_path, reproduction])
    # sort
    pairs_noisebandnet[texture_type].sort(key=lambda x: x[1])

print(pairs_noisebandnet)

def create_folder_from_wav(wav_path):
    # Get the name of the wav file without the extension
    wav_name = os.path.splitext(os.path.basename(wav_path))[0]
    # Get the directory where the wav file is located
    base_dir = os.path.dirname(wav_path)
    # Full path to the new folder
    folder_path = os.path.join(base_dir, wav_name)
    
    # Check if the folder already exists
    if os.path.exists(folder_path):
        print(f"Folder '{folder_path}' already exists.")
    else:
        print(f"Creating folder '{folder_path}'...")
        os.makedirs(folder_path)

    # Destination path for the copied wav file
    dest_wav_path = os.path.join(folder_path, os.path.basename(wav_path))
    
    # Copy the wav file to the new folder
    shutil.copy2(wav_path, dest_wav_path)
    print(f"Copied '{wav_path}' to '{dest_wav_path}'")

    return folder_path
# Out:
# {'bubbles': [['evaluation_sounds_texDSP/bubbles.wav', 'evaluation_sounds_texDSP/bubbles_1.wav'], ['evaluation_sounds_texDSP/bubbles.wav', 'evaluation_sounds_texDSP/bubbles_2.wav'], ['evaluation_sounds_texDSP/bubbles.wav', 'evaluation_sounds_texDSP/bubbles_3.wav'], ['evaluation_sounds_texDSP/bubbles.wav', 'evaluation_sounds_texDSP/bubbles_4.wav']], 'fire': [['evaluation_sounds_texDSP/fire.wav', 'evaluation_sounds_texDSP/fire_1.wav'], ['evaluation_sounds_texDSP/fire.wav', 'evaluation_sounds_texDSP/fire_2.wav'], ['evaluation_sounds_texDSP/fire.wav', 'evaluation_sounds_texDSP/fire_3.wav'], ['evaluation_sounds_texDSP/fire.wav', 'evaluation_sounds_texDSP/fire_4.wav'], ['evaluation_sounds_texDSP/fire.wav', 'evaluation_sounds_texDSP/fire_5.wav']], 'keyboard': [['evaluation_sounds_texDSP/keyboard.wav', 'evaluation_sounds_texDSP/keyboard_1.wav']], 'rain': [['evaluation_sounds_texDSP/rain.wav', 'evaluation_sounds_texDSP/rain_1.wav'], ['evaluation_sounds_texDSP/rain.wav', 'evaluation_sounds_texDSP/rain_2.wav']], 'river': [['evaluation_sounds_texDSP/river.wav', 'evaluation_sounds_texDSP/river_1.wav'], ['evaluation_sounds_texDSP/river.wav', 'evaluation_sounds_texDSP/river_2.wav'], ['evaluation_sounds_texDSP/river.wav', 'evaluation_sounds_texDSP/river_3.wav']], 'shards': [['evaluation_sounds_texDSP/shards.wav', 'evaluation_sounds_texDSP/shards_1.wav']], 'waterfall': [['evaluation_sounds_texDSP/waterfall.wav', 'evaluation_sounds_texDSP/waterfall_1.wav'], ['evaluation_sounds_texDSP/waterfall.wav', 'evaluation_sounds_texDSP/waterfall_2.wav']], 'wind': [['evaluation_sounds_texDSP/wind.wav', 'evaluation_sounds_texDSP/wind_1.wav'], ['evaluation_sounds_texDSP/wind.wav', 'evaluation_sounds_texDSP/wind_2.wav']]}
# {'bubbles': [['evaluation_sounds_noisebandnet/bubbles.wav', 'evaluation_sounds_noisebandnet/bubbles_resynth.wav']], 'fire': [['evaluation_sounds_noisebandnet/fire.wav', 'evaluation_sounds_noisebandnet/fire_resynth.wav']], 'keyboard': [['evaluation_sounds_noisebandnet/keyboard.wav', 'evaluation_sounds_noisebandnet/keyboard_resynth.wav']], 'rain': [['evaluation_sounds_noisebandnet/rain.wav', 'evaluation_sounds_noisebandnet/rain_resynth.wav']], 'river': [['evaluation_sounds_noisebandnet/river.wav', 'evaluation_sounds_noisebandnet/river_resynth.wav']], 'shards': [['evaluation_sounds_noisebandnet/shards.wav', 'evaluation_sounds_noisebandnet/shards_resynth.wav']], 'waterfall': [['evaluation_sounds_noisebandnet/waterfall.wav', 'evaluation_sounds_noisebandnet/waterfall_resynth.wav']], 'wind': [['evaluation_sounds_noisebandnet/wind.wav', 'evaluation_sounds_noisebandnet/wind_resynth.wav']]}

# %% [markdown]
# ### 1. FAD using TexStat evaluation over texDSP and noisebandnet

# %%
def fad_texstat_evaluation(wav_path_1, wav_path_2, FAD_texstat):
    # Create a folder for the wav file
    path_1 = create_folder_from_wav(wav_path_1)
    path_2 = create_folder_from_wav(wav_path_2)
    
    # Compute the FAD score
    fad_score = FAD_texstat.score(path_1, path_2)

    # delete the folders
    shutil.rmtree(path_1)
    shutil.rmtree(path_2)
    
    return fad_score

FAD_texstat = FAD_wrapper(frame_size = 44100, sampling_rate = 44100, device='cpu')

# %%
# Evaluate the pairs for texDSP
results={}
for texture_type, pairs in pairs_texDSP.items():
    print(f"Evaluating texture type: {texture_type}")
    for pair in pairs:
        score = fad_texstat_evaluation(pair[0], pair[1], FAD_texstat)
        results[pair[1]] = score

print("Results for texDSP:")
for texture_type, scores in results.items():
    print(f"{texture_type}: {scores}")
# Out:
# Evaluating texture type: bubbles
# Creating folder 'evaluation_sounds_texDSP/bubbles'...
# Copied 'evaluation_sounds_texDSP/bubbles.wav' to 'evaluation_sounds_texDSP/bubbles/bubbles.wav'
# Creating folder 'evaluation_sounds_texDSP/bubbles_1'...
# Copied 'evaluation_sounds_texDSP/bubbles_1.wav' to 'evaluation_sounds_texDSP/bubbles_1/bubbles_1.wav'
# Processing folder: bubbles
# Found 1 files in evaluation_sounds_texDSP/bubbles
#     Segmented 120 segments from evaluation_sounds_texDSP/bubbles/bubbles.wav
# Total segments: 120
# Processed 120 segments in evaluation_sounds_texDSP/bubbles
# Processing folder: bubbles_1
# Found 1 files in evaluation_sounds_texDSP/bubbles_1
#     Segmented 119 segments from evaluation_sounds_texDSP/bubbles_1/bubbles_1.wav
# Total segments: 119
# Processed 119 segments in evaluation_sounds_texDSP/bubbles_1
# Creating folder 'evaluation_sounds_texDSP/bubbles'...
# Copied 'evaluation_sounds_texDSP/bubbles.wav' to 'evaluation_sounds_texDSP/bubbles/bubbles.wav'
# Creating folder 'evaluation_sounds_texDSP/bubbles_2'...
# Copied 'evaluation_sounds_texDSP/bubbles_2.wav' to 'evaluation_sounds_texDSP/bubbles_2/bubbles_2.wav'
# Processing folder: bubbles
# Found 1 files in evaluation_sounds_texDSP/bubbles
#     Segmented 120 segments from evaluation_sounds_texDSP/bubbles/bubbles.wav
# Total segments: 120
# Processed 120 segments in evaluation_sounds_texDSP/bubbles
# Processing folder: bubbles_2
# Found 1 files in evaluation_sounds_texDSP/bubbles_2
#     Segmented 118 segments from evaluation_sounds_texDSP/bubbles_2/bubbles_2.wav
# Total segments: 118
# Processed 118 segments in evaluation_sounds_texDSP/bubbles_2
# Creating folder 'evaluation_sounds_texDSP/bubbles'...
# Copied 'evaluation_sounds_texDSP/bubbles.wav' to 'evaluation_sounds_texDSP/bubbles/bubbles.wav'
# Creating folder 'evaluation_sounds_texDSP/bubbles_3'...
# Copied 'evaluation_sounds_texDSP/bubbles_3.wav' to 'evaluation_sounds_texDSP/bubbles_3/bubbles_3.wav'
# Processing folder: bubbles
# Found 1 files in evaluation_sounds_texDSP/bubbles
#     Segmented 120 segments from evaluation_sounds_texDSP/bubbles/bubbles.wav
# Total segments: 120
# Processed 120 segments in evaluation_sounds_texDSP/bubbles
# Processing folder: bubbles_3
# Found 1 files in evaluation_sounds_texDSP/bubbles_3
#     Segmented 118 segments from evaluation_sounds_texDSP/bubbles_3/bubbles_3.wav
# Total segments: 118
# Processed 118 segments in evaluation_sounds_texDSP/bubbles_3
# Creating folder 'evaluation_sounds_texDSP/bubbles'...
# Copied 'evaluation_sounds_texDSP/bubbles.wav' to 'evaluation_sounds_texDSP/bubbles/bubbles.wav'
# Creating folder 'evaluation_sounds_texDSP/bubbles_4'...
# Copied 'evaluation_sounds_texDSP/bubbles_4.wav' to 'evaluation_sounds_texDSP/bubbles_4/bubbles_4.wav'
# Processing folder: bubbles
# Found 1 files in evaluation_sounds_texDSP/bubbles
#     Segmented 120 segments from evaluation_sounds_texDSP/bubbles/bubbles.wav
# Total segments: 120
# Processed 120 segments in evaluation_sounds_texDSP/bubbles
# Processing folder: bubbles_4
# Found 1 files in evaluation_sounds_texDSP/bubbles_4
#     Segmented 119 segments from evaluation_sounds_texDSP/bubbles_4/bubbles_4.wav
# Total segments: 119
# Processed 119 segments in evaluation_sounds_texDSP/bubbles_4
# Evaluating texture type: fire
# Creating folder 'evaluation_sounds_texDSP/fire'...
# Copied 'evaluation_sounds_texDSP/fire.wav' to 'evaluation_sounds_texDSP/fire/fire.wav'
# Creating folder 'evaluation_sounds_texDSP/fire_1'...
# Copied 'evaluation_sounds_texDSP/fire_1.wav' to 'evaluation_sounds_texDSP/fire_1/fire_1.wav'
# Processing folder: fire
# Found 1 files in evaluation_sounds_texDSP/fire
#     Segmented 120 segments from evaluation_sounds_texDSP/fire/fire.wav
# Total segments: 120
# Processed 120 segments in evaluation_sounds_texDSP/fire
# Processing folder: fire_1
# Found 1 files in evaluation_sounds_texDSP/fire_1
#     Segmented 119 segments from evaluation_sounds_texDSP/fire_1/fire_1.wav
# Total segments: 119
# Processed 119 segments in evaluation_sounds_texDSP/fire_1
# Creating folder 'evaluation_sounds_texDSP/fire'...
# Copied 'evaluation_sounds_texDSP/fire.wav' to 'evaluation_sounds_texDSP/fire/fire.wav'
# Creating folder 'evaluation_sounds_texDSP/fire_2'...
# Copied 'evaluation_sounds_texDSP/fire_2.wav' to 'evaluation_sounds_texDSP/fire_2/fire_2.wav'
# Processing folder: fire
# Found 1 files in evaluation_sounds_texDSP/fire
#     Segmented 120 segments from evaluation_sounds_texDSP/fire/fire.wav
# Total segments: 120
# Processed 120 segments in evaluation_sounds_texDSP/fire
# Processing folder: fire_2
# Found 1 files in evaluation_sounds_texDSP/fire_2
#     Segmented 119 segments from evaluation_sounds_texDSP/fire_2/fire_2.wav
# Total segments: 119
# Processed 119 segments in evaluation_sounds_texDSP/fire_2
# Creating folder 'evaluation_sounds_texDSP/fire'...
# Copied 'evaluation_sounds_texDSP/fire.wav' to 'evaluation_sounds_texDSP/fire/fire.wav'
# Creating folder 'evaluation_sounds_texDSP/fire_3'...
# Copied 'evaluation_sounds_texDSP/fire_3.wav' to 'evaluation_sounds_texDSP/fire_3/fire_3.wav'
# Processing folder: fire
# Found 1 files in evaluation_sounds_texDSP/fire
#     Segmented 120 segments from evaluation_sounds_texDSP/fire/fire.wav
# Total segments: 120
# Processed 120 segments in evaluation_sounds_texDSP/fire
# Processing folder: fire_3
# Found 1 files in evaluation_sounds_texDSP/fire_3
#     Segmented 119 segments from evaluation_sounds_texDSP/fire_3/fire_3.wav
# Total segments: 119
# Processed 119 segments in evaluation_sounds_texDSP/fire_3
# Creating folder 'evaluation_sounds_texDSP/fire'...
# Copied 'evaluation_sounds_texDSP/fire.wav' to 'evaluation_sounds_texDSP/fire/fire.wav'
# Creating folder 'evaluation_sounds_texDSP/fire_4'...
# Copied 'evaluation_sounds_texDSP/fire_4.wav' to 'evaluation_sounds_texDSP/fire_4/fire_4.wav'
# Processing folder: fire
# Found 1 files in evaluation_sounds_texDSP/fire
#     Segmented 120 segments from evaluation_sounds_texDSP/fire/fire.wav
# Total segments: 120
# Processed 120 segments in evaluation_sounds_texDSP/fire
# Processing folder: fire_4
# Found 1 files in evaluation_sounds_texDSP/fire_4
#     Segmented 119 segments from evaluation_sounds_texDSP/fire_4/fire_4.wav
# Total segments: 119
# Processed 119 segments in evaluation_sounds_texDSP/fire_4
# Creating folder 'evaluation_sounds_texDSP/fire'...
# Copied 'evaluation_sounds_texDSP/fire.wav' to 'evaluation_sounds_texDSP/fire/fire.wav'
# Creating folder 'evaluation_sounds_texDSP/fire_5'...
# Copied 'evaluation_sounds_texDSP/fire_5.wav' to 'evaluation_sounds_texDSP/fire_5/fire_5.wav'
# Processing folder: fire
# Found 1 files in evaluation_sounds_texDSP/fire
#     Segmented 120 segments from evaluation_sounds_texDSP/fire/fire.wav
# Total segments: 120
# Processed 120 segments in evaluation_sounds_texDSP/fire
# Processing folder: fire_5
# Found 1 files in evaluation_sounds_texDSP/fire_5
#     Segmented 119 segments from evaluation_sounds_texDSP/fire_5/fire_5.wav
# Total segments: 119
# Processed 119 segments in evaluation_sounds_texDSP/fire_5
# Evaluating texture type: keyboard
# Creating folder 'evaluation_sounds_texDSP/keyboard'...
# Copied 'evaluation_sounds_texDSP/keyboard.wav' to 'evaluation_sounds_texDSP/keyboard/keyboard.wav'
# Creating folder 'evaluation_sounds_texDSP/keyboard_1'...
# Copied 'evaluation_sounds_texDSP/keyboard_1.wav' to 'evaluation_sounds_texDSP/keyboard_1/keyboard_1.wav'
# Processing folder: keyboard
# Found 1 files in evaluation_sounds_texDSP/keyboard
#     Segmented 120 segments from evaluation_sounds_texDSP/keyboard/keyboard.wav
# Total segments: 120
# Processed 120 segments in evaluation_sounds_texDSP/keyboard
# Processing folder: keyboard_1
# Found 1 files in evaluation_sounds_texDSP/keyboard_1
#     Segmented 119 segments from evaluation_sounds_texDSP/keyboard_1/keyboard_1.wav
# Total segments: 119
# Processed 119 segments in evaluation_sounds_texDSP/keyboard_1
# Evaluating texture type: rain
# Creating folder 'evaluation_sounds_texDSP/rain'...
# Copied 'evaluation_sounds_texDSP/rain.wav' to 'evaluation_sounds_texDSP/rain/rain.wav'
# Creating folder 'evaluation_sounds_texDSP/rain_1'...
# Copied 'evaluation_sounds_texDSP/rain_1.wav' to 'evaluation_sounds_texDSP/rain_1/rain_1.wav'
# Processing folder: rain
# Found 1 files in evaluation_sounds_texDSP/rain
#     Segmented 120 segments from evaluation_sounds_texDSP/rain/rain.wav
# Total segments: 120
# Processed 120 segments in evaluation_sounds_texDSP/rain
# Processing folder: rain_1
# Found 1 files in evaluation_sounds_texDSP/rain_1
#     Segmented 118 segments from evaluation_sounds_texDSP/rain_1/rain_1.wav
# Total segments: 118
# Processed 118 segments in evaluation_sounds_texDSP/rain_1
# Creating folder 'evaluation_sounds_texDSP/rain'...
# Copied 'evaluation_sounds_texDSP/rain.wav' to 'evaluation_sounds_texDSP/rain/rain.wav'
# Creating folder 'evaluation_sounds_texDSP/rain_2'...
# Copied 'evaluation_sounds_texDSP/rain_2.wav' to 'evaluation_sounds_texDSP/rain_2/rain_2.wav'
# Processing folder: rain
# Found 1 files in evaluation_sounds_texDSP/rain
#     Segmented 120 segments from evaluation_sounds_texDSP/rain/rain.wav
# Total segments: 120
# Processed 120 segments in evaluation_sounds_texDSP/rain
# Processing folder: rain_2
# Found 1 files in evaluation_sounds_texDSP/rain_2
#     Segmented 119 segments from evaluation_sounds_texDSP/rain_2/rain_2.wav
# Total segments: 119
# Processed 119 segments in evaluation_sounds_texDSP/rain_2
# Evaluating texture type: river
# Creating folder 'evaluation_sounds_texDSP/river'...
# Copied 'evaluation_sounds_texDSP/river.wav' to 'evaluation_sounds_texDSP/river/river.wav'
# Creating folder 'evaluation_sounds_texDSP/river_1'...
# Copied 'evaluation_sounds_texDSP/river_1.wav' to 'evaluation_sounds_texDSP/river_1/river_1.wav'
# Processing folder: river
# Found 1 files in evaluation_sounds_texDSP/river
#     Segmented 120 segments from evaluation_sounds_texDSP/river/river.wav
# Total segments: 120
# Processed 120 segments in evaluation_sounds_texDSP/river
# Processing folder: river_1
# Found 1 files in evaluation_sounds_texDSP/river_1
#     Segmented 119 segments from evaluation_sounds_texDSP/river_1/river_1.wav
# Total segments: 119
# Processed 119 segments in evaluation_sounds_texDSP/river_1
# Creating folder 'evaluation_sounds_texDSP/river'...
# Copied 'evaluation_sounds_texDSP/river.wav' to 'evaluation_sounds_texDSP/river/river.wav'
# Creating folder 'evaluation_sounds_texDSP/river_2'...
# Copied 'evaluation_sounds_texDSP/river_2.wav' to 'evaluation_sounds_texDSP/river_2/river_2.wav'
# Processing folder: river
# Found 1 files in evaluation_sounds_texDSP/river
#     Segmented 120 segments from evaluation_sounds_texDSP/river/river.wav
# Total segments: 120
# Processed 120 segments in evaluation_sounds_texDSP/river
# Processing folder: river_2
# Found 1 files in evaluation_sounds_texDSP/river_2
#     Segmented 119 segments from evaluation_sounds_texDSP/river_2/river_2.wav
# Total segments: 119
# Processed 119 segments in evaluation_sounds_texDSP/river_2
# Creating folder 'evaluation_sounds_texDSP/river'...
# Copied 'evaluation_sounds_texDSP/river.wav' to 'evaluation_sounds_texDSP/river/river.wav'
# Creating folder 'evaluation_sounds_texDSP/river_3'...
# Copied 'evaluation_sounds_texDSP/river_3.wav' to 'evaluation_sounds_texDSP/river_3/river_3.wav'
# Processing folder: river
# Found 1 files in evaluation_sounds_texDSP/river
#     Segmented 120 segments from evaluation_sounds_texDSP/river/river.wav
# Total segments: 120
# Processed 120 segments in evaluation_sounds_texDSP/river
# Processing folder: river_3
# Found 1 files in evaluation_sounds_texDSP/river_3
#     Segmented 119 segments from evaluation_sounds_texDSP/river_3/river_3.wav
# Total segments: 119
# Processed 119 segments in evaluation_sounds_texDSP/river_3
# Evaluating texture type: shards
# Creating folder 'evaluation_sounds_texDSP/shards'...
# Copied 'evaluation_sounds_texDSP/shards.wav' to 'evaluation_sounds_texDSP/shards/shards.wav'
# Creating folder 'evaluation_sounds_texDSP/shards_1'...
# Copied 'evaluation_sounds_texDSP/shards_1.wav' to 'evaluation_sounds_texDSP/shards_1/shards_1.wav'
# Processing folder: shards
# Found 1 files in evaluation_sounds_texDSP/shards
#     Segmented 120 segments from evaluation_sounds_texDSP/shards/shards.wav
# Total segments: 120
# Processed 120 segments in evaluation_sounds_texDSP/shards
# Processing folder: shards_1
# Found 1 files in evaluation_sounds_texDSP/shards_1
#     Segmented 118 segments from evaluation_sounds_texDSP/shards_1/shards_1.wav
# Total segments: 118
# Processed 118 segments in evaluation_sounds_texDSP/shards_1
# Evaluating texture type: waterfall
# Creating folder 'evaluation_sounds_texDSP/waterfall'...
# Copied 'evaluation_sounds_texDSP/waterfall.wav' to 'evaluation_sounds_texDSP/waterfall/waterfall.wav'
# Creating folder 'evaluation_sounds_texDSP/waterfall_1'...
# Copied 'evaluation_sounds_texDSP/waterfall_1.wav' to 'evaluation_sounds_texDSP/waterfall_1/waterfall_1.wav'
# Processing folder: waterfall
# Found 1 files in evaluation_sounds_texDSP/waterfall
#     Segmented 120 segments from evaluation_sounds_texDSP/waterfall/waterfall.wav
# Total segments: 120
# Processed 120 segments in evaluation_sounds_texDSP/waterfall
# Processing folder: waterfall_1
# Found 1 files in evaluation_sounds_texDSP/waterfall_1
#     Segmented 119 segments from evaluation_sounds_texDSP/waterfall_1/waterfall_1.wav
# Total segments: 119
# Processed 119 segments in evaluation_sounds_texDSP/waterfall_1
# Creating folder 'evaluation_sounds_texDSP/waterfall'...
# Copied 'evaluation_sounds_texDSP/waterfall.wav' to 'evaluation_sounds_texDSP/waterfall/waterfall.wav'
# Creating folder 'evaluation_sounds_texDSP/waterfall_2'...
# Copied 'evaluation_sounds_texDSP/waterfall_2.wav' to 'evaluation_sounds_texDSP/waterfall_2/waterfall_2.wav'
# Processing folder: waterfall
# Found 1 files in evaluation_sounds_texDSP/waterfall
#     Segmented 120 segments from evaluation_sounds_texDSP/waterfall/waterfall.wav
# Total segments: 120
# Processed 120 segments in evaluation_sounds_texDSP/waterfall
# Processing folder: waterfall_2
# Found 1 files in evaluation_sounds_texDSP/waterfall_2
#     Segmented 119 segments from evaluation_sounds_texDSP/waterfall_2/waterfall_2.wav
# Total segments: 119
# Processed 119 segments in evaluation_sounds_texDSP/waterfall_2
# Evaluating texture type: wind
# Creating folder 'evaluation_sounds_texDSP/wind'...
# Copied 'evaluation_sounds_texDSP/wind.wav' to 'evaluation_sounds_texDSP/wind/wind.wav'
# Creating folder 'evaluation_sounds_texDSP/wind_1'...
# Copied 'evaluation_sounds_texDSP/wind_1.wav' to 'evaluation_sounds_texDSP/wind_1/wind_1.wav'
# Processing folder: wind
# Found 1 files in evaluation_sounds_texDSP/wind
#     Segmented 120 segments from evaluation_sounds_texDSP/wind/wind.wav
# Total segments: 120
# Processed 120 segments in evaluation_sounds_texDSP/wind
# Processing folder: wind_1
# Found 1 files in evaluation_sounds_texDSP/wind_1
#     Segmented 119 segments from evaluation_sounds_texDSP/wind_1/wind_1.wav
# Total segments: 119
# Processed 119 segments in evaluation_sounds_texDSP/wind_1
# Creating folder 'evaluation_sounds_texDSP/wind'...
# Copied 'evaluation_sounds_texDSP/wind.wav' to 'evaluation_sounds_texDSP/wind/wind.wav'
# Creating folder 'evaluation_sounds_texDSP/wind_2'...
# Copied 'evaluation_sounds_texDSP/wind_2.wav' to 'evaluation_sounds_texDSP/wind_2/wind_2.wav'
# Processing folder: wind
# Found 1 files in evaluation_sounds_texDSP/wind
#     Segmented 120 segments from evaluation_sounds_texDSP/wind/wind.wav
# Total segments: 120
# Processed 120 segments in evaluation_sounds_texDSP/wind
# Processing folder: wind_2
# Found 1 files in evaluation_sounds_texDSP/wind_2
#     Segmented 119 segments from evaluation_sounds_texDSP/wind_2/wind_2.wav
# Total segments: 119
# Processed 119 segments in evaluation_sounds_texDSP/wind_2
# Results for texDSP:
# evaluation_sounds_texDSP/bubbles_1.wav: 2.230946283017002
# evaluation_sounds_texDSP/bubbles_2.wav: 3.0770762941810688
# evaluation_sounds_texDSP/bubbles_3.wav: 1.8636724201351305
# evaluation_sounds_texDSP/bubbles_4.wav: 3.97208214574914
# evaluation_sounds_texDSP/fire_1.wav: 6.142125848114616
# evaluation_sounds_texDSP/fire_2.wav: 6.87828245959284
# evaluation_sounds_texDSP/fire_3.wav: 6.72964083369103
# evaluation_sounds_texDSP/fire_4.wav: 6.777582395141648
# evaluation_sounds_texDSP/fire_5.wav: 12.272554840899303
# evaluation_sounds_texDSP/keyboard_1.wav: 16.63625646313801
# evaluation_sounds_texDSP/rain_1.wav: 1.2726881788908975
# evaluation_sounds_texDSP/rain_2.wav: 0.9878256011482824
# evaluation_sounds_texDSP/river_1.wav: 0.8058993843140854
# evaluation_sounds_texDSP/river_2.wav: 0.903254610965688
# evaluation_sounds_texDSP/river_3.wav: 2.2691790308095268
# evaluation_sounds_texDSP/shards_1.wav: 3.7968449958836166
# evaluation_sounds_texDSP/waterfall_1.wav: 0.6425733102274538
# evaluation_sounds_texDSP/waterfall_2.wav: 0.5296023328589561
# evaluation_sounds_texDSP/wind_1.wav: 1.9558264867371542
# evaluation_sounds_texDSP/wind_2.wav: 1.9782047858921574

# %%
# Evaluate the pairs for noisebandnet
results={}
for texture_type, pairs in pairs_noisebandnet.items():
    print(f"Evaluating texture type: {texture_type}")
    for pair in pairs:
        score = fad_texstat_evaluation(pair[0], pair[1], FAD_texstat)
        results[pair[1]] = score

print("Results for noisebandnet:")
for texture_type, scores in results.items():
    print(f"{texture_type}: {scores}")
# Out:
# Evaluating texture type: bubbles
# Creating folder 'evaluation_sounds_noisebandnet/bubbles'...
# Copied 'evaluation_sounds_noisebandnet/bubbles.wav' to 'evaluation_sounds_noisebandnet/bubbles/bubbles.wav'
# Creating folder 'evaluation_sounds_noisebandnet/bubbles_resynth'...
# Copied 'evaluation_sounds_noisebandnet/bubbles_resynth.wav' to 'evaluation_sounds_noisebandnet/bubbles_resynth/bubbles_resynth.wav'
# Processing folder: bubbles
# Found 1 files in evaluation_sounds_noisebandnet/bubbles
#     Segmented 120 segments from evaluation_sounds_noisebandnet/bubbles/bubbles.wav
# Total segments: 120
# Processed 120 segments in evaluation_sounds_noisebandnet/bubbles
# Processing folder: bubbles_resynth
# Found 1 files in evaluation_sounds_noisebandnet/bubbles_resynth
#     Segmented 119 segments from evaluation_sounds_noisebandnet/bubbles_resynth/bubbles_resynth.wav
# Total segments: 119
# Processed 119 segments in evaluation_sounds_noisebandnet/bubbles_resynth
# Evaluating texture type: fire
# Creating folder 'evaluation_sounds_noisebandnet/fire'...
# Copied 'evaluation_sounds_noisebandnet/fire.wav' to 'evaluation_sounds_noisebandnet/fire/fire.wav'
# Creating folder 'evaluation_sounds_noisebandnet/fire_resynth'...
# Copied 'evaluation_sounds_noisebandnet/fire_resynth.wav' to 'evaluation_sounds_noisebandnet/fire_resynth/fire_resynth.wav'
# Processing folder: fire
# Found 1 files in evaluation_sounds_noisebandnet/fire
#     Segmented 120 segments from evaluation_sounds_noisebandnet/fire/fire.wav
# Total segments: 120
# Processed 120 segments in evaluation_sounds_noisebandnet/fire
# Processing folder: fire_resynth
# Found 1 files in evaluation_sounds_noisebandnet/fire_resynth
#     Segmented 119 segments from evaluation_sounds_noisebandnet/fire_resynth/fire_resynth.wav
# Total segments: 119
# Processed 119 segments in evaluation_sounds_noisebandnet/fire_resynth
# Evaluating texture type: keyboard
# Creating folder 'evaluation_sounds_noisebandnet/keyboard'...
# Copied 'evaluation_sounds_noisebandnet/keyboard.wav' to 'evaluation_sounds_noisebandnet/keyboard/keyboard.wav'
# Creating folder 'evaluation_sounds_noisebandnet/keyboard_resynth'...
# Copied 'evaluation_sounds_noisebandnet/keyboard_resynth.wav' to 'evaluation_sounds_noisebandnet/keyboard_resynth/keyboard_resynth.wav'
# Processing folder: keyboard
# Found 1 files in evaluation_sounds_noisebandnet/keyboard
#     Segmented 120 segments from evaluation_sounds_noisebandnet/keyboard/keyboard.wav
# Total segments: 120
# Processed 120 segments in evaluation_sounds_noisebandnet/keyboard
# Processing folder: keyboard_resynth
# Found 1 files in evaluation_sounds_noisebandnet/keyboard_resynth
#     Segmented 119 segments from evaluation_sounds_noisebandnet/keyboard_resynth/keyboard_resynth.wav
# Total segments: 119
# Processed 119 segments in evaluation_sounds_noisebandnet/keyboard_resynth
# Evaluating texture type: rain
# Creating folder 'evaluation_sounds_noisebandnet/rain'...
# Copied 'evaluation_sounds_noisebandnet/rain.wav' to 'evaluation_sounds_noisebandnet/rain/rain.wav'
# Creating folder 'evaluation_sounds_noisebandnet/rain_resynth'...
# Copied 'evaluation_sounds_noisebandnet/rain_resynth.wav' to 'evaluation_sounds_noisebandnet/rain_resynth/rain_resynth.wav'
# Processing folder: rain
# Found 1 files in evaluation_sounds_noisebandnet/rain
#     Segmented 120 segments from evaluation_sounds_noisebandnet/rain/rain.wav
# Total segments: 120
# Processed 120 segments in evaluation_sounds_noisebandnet/rain
# Processing folder: rain_resynth
# Found 1 files in evaluation_sounds_noisebandnet/rain_resynth
#     Segmented 119 segments from evaluation_sounds_noisebandnet/rain_resynth/rain_resynth.wav
# Total segments: 119
# Processed 119 segments in evaluation_sounds_noisebandnet/rain_resynth
# Evaluating texture type: river
# Creating folder 'evaluation_sounds_noisebandnet/river'...
# Copied 'evaluation_sounds_noisebandnet/river.wav' to 'evaluation_sounds_noisebandnet/river/river.wav'
# Creating folder 'evaluation_sounds_noisebandnet/river_resynth'...
# Copied 'evaluation_sounds_noisebandnet/river_resynth.wav' to 'evaluation_sounds_noisebandnet/river_resynth/river_resynth.wav'
# Processing folder: river
# Found 1 files in evaluation_sounds_noisebandnet/river
#     Segmented 120 segments from evaluation_sounds_noisebandnet/river/river.wav
# Total segments: 120
# Processed 120 segments in evaluation_sounds_noisebandnet/river
# Processing folder: river_resynth
# Found 1 files in evaluation_sounds_noisebandnet/river_resynth
#     Segmented 119 segments from evaluation_sounds_noisebandnet/river_resynth/river_resynth.wav
# Total segments: 119
# Processed 119 segments in evaluation_sounds_noisebandnet/river_resynth
# Evaluating texture type: shards
# Creating folder 'evaluation_sounds_noisebandnet/shards'...
# Copied 'evaluation_sounds_noisebandnet/shards.wav' to 'evaluation_sounds_noisebandnet/shards/shards.wav'
# Creating folder 'evaluation_sounds_noisebandnet/shards_resynth'...
# Copied 'evaluation_sounds_noisebandnet/shards_resynth.wav' to 'evaluation_sounds_noisebandnet/shards_resynth/shards_resynth.wav'
# Processing folder: shards
# Found 1 files in evaluation_sounds_noisebandnet/shards
#     Segmented 120 segments from evaluation_sounds_noisebandnet/shards/shards.wav
# Total segments: 120
# Processed 120 segments in evaluation_sounds_noisebandnet/shards
# Processing folder: shards_resynth
# Found 1 files in evaluation_sounds_noisebandnet/shards_resynth
#     Segmented 119 segments from evaluation_sounds_noisebandnet/shards_resynth/shards_resynth.wav
# Total segments: 119
# Processed 119 segments in evaluation_sounds_noisebandnet/shards_resynth
# Evaluating texture type: waterfall
# Creating folder 'evaluation_sounds_noisebandnet/waterfall'...
# Copied 'evaluation_sounds_noisebandnet/waterfall.wav' to 'evaluation_sounds_noisebandnet/waterfall/waterfall.wav'
# Creating folder 'evaluation_sounds_noisebandnet/waterfall_resynth'...
# Copied 'evaluation_sounds_noisebandnet/waterfall_resynth.wav' to 'evaluation_sounds_noisebandnet/waterfall_resynth/waterfall_resynth.wav'
# Processing folder: waterfall
# Found 1 files in evaluation_sounds_noisebandnet/waterfall
#     Segmented 120 segments from evaluation_sounds_noisebandnet/waterfall/waterfall.wav
# Total segments: 120
# Processed 120 segments in evaluation_sounds_noisebandnet/waterfall
# Processing folder: waterfall_resynth
# Found 1 files in evaluation_sounds_noisebandnet/waterfall_resynth
#     Segmented 119 segments from evaluation_sounds_noisebandnet/waterfall_resynth/waterfall_resynth.wav
# Total segments: 119
# Processed 119 segments in evaluation_sounds_noisebandnet/waterfall_resynth
# Evaluating texture type: wind
# Creating folder 'evaluation_sounds_noisebandnet/wind'...
# Copied 'evaluation_sounds_noisebandnet/wind.wav' to 'evaluation_sounds_noisebandnet/wind/wind.wav'
# Creating folder 'evaluation_sounds_noisebandnet/wind_resynth'...
# Copied 'evaluation_sounds_noisebandnet/wind_resynth.wav' to 'evaluation_sounds_noisebandnet/wind_resynth/wind_resynth.wav'
# Processing folder: wind
# Found 1 files in evaluation_sounds_noisebandnet/wind
#     Segmented 120 segments from evaluation_sounds_noisebandnet/wind/wind.wav
# Total segments: 120
# Processed 120 segments in evaluation_sounds_noisebandnet/wind
# Processing folder: wind_resynth
# Found 1 files in evaluation_sounds_noisebandnet/wind_resynth
#     Segmented 119 segments from evaluation_sounds_noisebandnet/wind_resynth/wind_resynth.wav
# Total segments: 119
# Processed 119 segments in evaluation_sounds_noisebandnet/wind_resynth
# Results for noisebandnet:
# evaluation_sounds_noisebandnet/bubbles_resynth.wav: 1.1476968032093748
# evaluation_sounds_noisebandnet/fire_resynth.wav: 1.5190855752355397
# evaluation_sounds_noisebandnet/keyboard_resynth.wav: 277.1261265371893
# evaluation_sounds_noisebandnet/rain_resynth.wav: 6.191267156493839
# evaluation_sounds_noisebandnet/river_resynth.wav: 1.751095671047102
# evaluation_sounds_noisebandnet/shards_resynth.wav: 7.579208903808903
# evaluation_sounds_noisebandnet/waterfall_resynth.wav: 1.0573400462898421
# evaluation_sounds_noisebandnet/wind_resynth.wav: 8.478061127668973

# %% [markdown]
# ### 2. FAD using VGGish

# %%
def fad_evaluation(wav_path_1, wav_path_2, frechet):
    # Create a folder for the wav file
    path_1 = create_folder_from_wav(wav_path_1)
    path_2 = create_folder_from_wav(wav_path_2)
    
    # Compute the FAD score
    fad_score = frechet.score(
        path_1,
        path_2,
        dtype="float32"
    )

    # delete the folders
    shutil.rmtree(path_1)
    shutil.rmtree(path_2)
    
    return fad_score

# to use `vggish`
frechet = FrechetAudioDistance(
    model_name="vggish",
    sample_rate=16000,
    use_pca=False, 
    use_activation=False,
    verbose=False
)
# Out:
# Using cache found in /home/esteban/.cache/torch/hub/harritaylor_torchvggish_master

# %%
# Evaluate the pairs for texDSP
results={}
for texture_type, pairs in pairs_texDSP.items():
    print(f"Evaluating texture type: {texture_type}")
    for pair in pairs:
        score = fad_evaluation(pair[0], pair[1], frechet)
        results[pair[1]] = score

print("Results for noisebandnet:")
for texture_type, scores in results.items():
    print(f"{texture_type}: {scores}")
# Out:
# Evaluating texture type: bubbles
# Creating folder 'evaluation_sounds_texDSP/bubbles'...
# Copied 'evaluation_sounds_texDSP/bubbles.wav' to 'evaluation_sounds_texDSP/bubbles/bubbles.wav'
# Creating folder 'evaluation_sounds_texDSP/bubbles_1'...
# Copied 'evaluation_sounds_texDSP/bubbles_1.wav' to 'evaluation_sounds_texDSP/bubbles_1/bubbles_1.wav'
# Creating folder 'evaluation_sounds_texDSP/bubbles'...
# Copied 'evaluation_sounds_texDSP/bubbles.wav' to 'evaluation_sounds_texDSP/bubbles/bubbles.wav'
# Creating folder 'evaluation_sounds_texDSP/bubbles_2'...
# Copied 'evaluation_sounds_texDSP/bubbles_2.wav' to 'evaluation_sounds_texDSP/bubbles_2/bubbles_2.wav'
# Creating folder 'evaluation_sounds_texDSP/bubbles'...
# Copied 'evaluation_sounds_texDSP/bubbles.wav' to 'evaluation_sounds_texDSP/bubbles/bubbles.wav'
# Creating folder 'evaluation_sounds_texDSP/bubbles_3'...
# Copied 'evaluation_sounds_texDSP/bubbles_3.wav' to 'evaluation_sounds_texDSP/bubbles_3/bubbles_3.wav'
# Creating folder 'evaluation_sounds_texDSP/bubbles'...
# Copied 'evaluation_sounds_texDSP/bubbles.wav' to 'evaluation_sounds_texDSP/bubbles/bubbles.wav'
# Creating folder 'evaluation_sounds_texDSP/bubbles_4'...
# Copied 'evaluation_sounds_texDSP/bubbles_4.wav' to 'evaluation_sounds_texDSP/bubbles_4/bubbles_4.wav'
# Evaluating texture type: fire
# Creating folder 'evaluation_sounds_texDSP/fire'...
# Copied 'evaluation_sounds_texDSP/fire.wav' to 'evaluation_sounds_texDSP/fire/fire.wav'
# Creating folder 'evaluation_sounds_texDSP/fire_1'...
# Copied 'evaluation_sounds_texDSP/fire_1.wav' to 'evaluation_sounds_texDSP/fire_1/fire_1.wav'
# Creating folder 'evaluation_sounds_texDSP/fire'...
# Copied 'evaluation_sounds_texDSP/fire.wav' to 'evaluation_sounds_texDSP/fire/fire.wav'
# Creating folder 'evaluation_sounds_texDSP/fire_2'...
# Copied 'evaluation_sounds_texDSP/fire_2.wav' to 'evaluation_sounds_texDSP/fire_2/fire_2.wav'
# Creating folder 'evaluation_sounds_texDSP/fire'...
# Copied 'evaluation_sounds_texDSP/fire.wav' to 'evaluation_sounds_texDSP/fire/fire.wav'
# Creating folder 'evaluation_sounds_texDSP/fire_3'...
# Copied 'evaluation_sounds_texDSP/fire_3.wav' to 'evaluation_sounds_texDSP/fire_3/fire_3.wav'
# Creating folder 'evaluation_sounds_texDSP/fire'...
# Copied 'evaluation_sounds_texDSP/fire.wav' to 'evaluation_sounds_texDSP/fire/fire.wav'
# Creating folder 'evaluation_sounds_texDSP/fire_4'...
# Copied 'evaluation_sounds_texDSP/fire_4.wav' to 'evaluation_sounds_texDSP/fire_4/fire_4.wav'
# Creating folder 'evaluation_sounds_texDSP/fire'...
# Copied 'evaluation_sounds_texDSP/fire.wav' to 'evaluation_sounds_texDSP/fire/fire.wav'
# Creating folder 'evaluation_sounds_texDSP/fire_5'...
# Copied 'evaluation_sounds_texDSP/fire_5.wav' to 'evaluation_sounds_texDSP/fire_5/fire_5.wav'
# Evaluating texture type: keyboard
# Creating folder 'evaluation_sounds_texDSP/keyboard'...
# Copied 'evaluation_sounds_texDSP/keyboard.wav' to 'evaluation_sounds_texDSP/keyboard/keyboard.wav'
# Creating folder 'evaluation_sounds_texDSP/keyboard_1'...
# Copied 'evaluation_sounds_texDSP/keyboard_1.wav' to 'evaluation_sounds_texDSP/keyboard_1/keyboard_1.wav'
# Evaluating texture type: rain
# Creating folder 'evaluation_sounds_texDSP/rain'...
# Copied 'evaluation_sounds_texDSP/rain.wav' to 'evaluation_sounds_texDSP/rain/rain.wav'
# Creating folder 'evaluation_sounds_texDSP/rain_1'...
# Copied 'evaluation_sounds_texDSP/rain_1.wav' to 'evaluation_sounds_texDSP/rain_1/rain_1.wav'
# Creating folder 'evaluation_sounds_texDSP/rain'...
# Copied 'evaluation_sounds_texDSP/rain.wav' to 'evaluation_sounds_texDSP/rain/rain.wav'
# Creating folder 'evaluation_sounds_texDSP/rain_2'...
# Copied 'evaluation_sounds_texDSP/rain_2.wav' to 'evaluation_sounds_texDSP/rain_2/rain_2.wav'
# Evaluating texture type: river
# Creating folder 'evaluation_sounds_texDSP/river'...
# Copied 'evaluation_sounds_texDSP/river.wav' to 'evaluation_sounds_texDSP/river/river.wav'
# Creating folder 'evaluation_sounds_texDSP/river_1'...
# Copied 'evaluation_sounds_texDSP/river_1.wav' to 'evaluation_sounds_texDSP/river_1/river_1.wav'
# Creating folder 'evaluation_sounds_texDSP/river'...
# Copied 'evaluation_sounds_texDSP/river.wav' to 'evaluation_sounds_texDSP/river/river.wav'
# Creating folder 'evaluation_sounds_texDSP/river_2'...
# Copied 'evaluation_sounds_texDSP/river_2.wav' to 'evaluation_sounds_texDSP/river_2/river_2.wav'
# Creating folder 'evaluation_sounds_texDSP/river'...
# Copied 'evaluation_sounds_texDSP/river.wav' to 'evaluation_sounds_texDSP/river/river.wav'
# Creating folder 'evaluation_sounds_texDSP/river_3'...
# Copied 'evaluation_sounds_texDSP/river_3.wav' to 'evaluation_sounds_texDSP/river_3/river_3.wav'
# Evaluating texture type: shards
# Creating folder 'evaluation_sounds_texDSP/shards'...
# Copied 'evaluation_sounds_texDSP/shards.wav' to 'evaluation_sounds_texDSP/shards/shards.wav'
# Creating folder 'evaluation_sounds_texDSP/shards_1'...
# Copied 'evaluation_sounds_texDSP/shards_1.wav' to 'evaluation_sounds_texDSP/shards_1/shards_1.wav'
# Evaluating texture type: waterfall
# Creating folder 'evaluation_sounds_texDSP/waterfall'...
# Copied 'evaluation_sounds_texDSP/waterfall.wav' to 'evaluation_sounds_texDSP/waterfall/waterfall.wav'
# Creating folder 'evaluation_sounds_texDSP/waterfall_1'...
# Copied 'evaluation_sounds_texDSP/waterfall_1.wav' to 'evaluation_sounds_texDSP/waterfall_1/waterfall_1.wav'
# Creating folder 'evaluation_sounds_texDSP/waterfall'...
# Copied 'evaluation_sounds_texDSP/waterfall.wav' to 'evaluation_sounds_texDSP/waterfall/waterfall.wav'
# Creating folder 'evaluation_sounds_texDSP/waterfall_2'...
# Copied 'evaluation_sounds_texDSP/waterfall_2.wav' to 'evaluation_sounds_texDSP/waterfall_2/waterfall_2.wav'
# Evaluating texture type: wind
# Creating folder 'evaluation_sounds_texDSP/wind'...
# Copied 'evaluation_sounds_texDSP/wind.wav' to 'evaluation_sounds_texDSP/wind/wind.wav'
# Creating folder 'evaluation_sounds_texDSP/wind_1'...
# Copied 'evaluation_sounds_texDSP/wind_1.wav' to 'evaluation_sounds_texDSP/wind_1/wind_1.wav'
# Creating folder 'evaluation_sounds_texDSP/wind'...
# Copied 'evaluation_sounds_texDSP/wind.wav' to 'evaluation_sounds_texDSP/wind/wind.wav'
# Creating folder 'evaluation_sounds_texDSP/wind_2'...
# Copied 'evaluation_sounds_texDSP/wind_2.wav' to 'evaluation_sounds_texDSP/wind_2/wind_2.wav'
# Results for noisebandnet:
# evaluation_sounds_texDSP/bubbles_1.wav: 47.09043037673105
# evaluation_sounds_texDSP/bubbles_2.wav: 43.953164125209796
# evaluation_sounds_texDSP/bubbles_3.wav: 35.20635267231033
# evaluation_sounds_texDSP/bubbles_4.wav: 71.5824961879962
# evaluation_sounds_texDSP/fire_1.wav: 15.034228168030905
# evaluation_sounds_texDSP/fire_2.wav: 13.105554407032692
# evaluation_sounds_texDSP/fire_3.wav: 15.266531274713504
# evaluation_sounds_texDSP/fire_4.wav: 12.144649838722042
# evaluation_sounds_texDSP/fire_5.wav: 11.864191218695556
# evaluation_sounds_texDSP/keyboard_1.wav: 13.016241777423133
# evaluation_sounds_texDSP/rain_1.wav: 11.72538427799473
# evaluation_sounds_texDSP/rain_2.wav: 9.09234613082102
# evaluation_sounds_texDSP/river_1.wav: 43.657609847961595
# evaluation_sounds_texDSP/river_2.wav: 45.95248853751595
# evaluation_sounds_texDSP/river_3.wav: 52.74369548695852
# evaluation_sounds_texDSP/shards_1.wav: 4.635880397638569
# evaluation_sounds_texDSP/waterfall_1.wav: 19.471284823425787
# evaluation_sounds_texDSP/waterfall_2.wav: 18.230398495681126
# evaluation_sounds_texDSP/wind_1.wav: 10.942112751983107
# evaluation_sounds_texDSP/wind_2.wav: 9.662151318453446

# %%
# Evaluate the pairs for noisebandnet
results={}
for texture_type, pairs in pairs_noisebandnet.items():
    print(f"Evaluating texture type: {texture_type}")
    for pair in pairs:
        score = fad_evaluation(pair[0], pair[1], frechet)
        results[pair[1]] = score

print("Results for noisebandnet:")
for texture_type, scores in results.items():
    print(f"{texture_type}: {scores}")
# Out:
# Evaluating texture type: bubbles
# Creating folder 'evaluation_sounds_noisebandnet/bubbles'...
# Copied 'evaluation_sounds_noisebandnet/bubbles.wav' to 'evaluation_sounds_noisebandnet/bubbles/bubbles.wav'
# Creating folder 'evaluation_sounds_noisebandnet/bubbles_resynth'...
# Copied 'evaluation_sounds_noisebandnet/bubbles_resynth.wav' to 'evaluation_sounds_noisebandnet/bubbles_resynth/bubbles_resynth.wav'
# Evaluating texture type: fire
# Creating folder 'evaluation_sounds_noisebandnet/fire'...
# Copied 'evaluation_sounds_noisebandnet/fire.wav' to 'evaluation_sounds_noisebandnet/fire/fire.wav'
# Creating folder 'evaluation_sounds_noisebandnet/fire_resynth'...
# Copied 'evaluation_sounds_noisebandnet/fire_resynth.wav' to 'evaluation_sounds_noisebandnet/fire_resynth/fire_resynth.wav'
# Evaluating texture type: keyboard
# Creating folder 'evaluation_sounds_noisebandnet/keyboard'...
# Copied 'evaluation_sounds_noisebandnet/keyboard.wav' to 'evaluation_sounds_noisebandnet/keyboard/keyboard.wav'
# Creating folder 'evaluation_sounds_noisebandnet/keyboard_resynth'...
# Copied 'evaluation_sounds_noisebandnet/keyboard_resynth.wav' to 'evaluation_sounds_noisebandnet/keyboard_resynth/keyboard_resynth.wav'
# Evaluating texture type: rain
# Creating folder 'evaluation_sounds_noisebandnet/rain'...
# Copied 'evaluation_sounds_noisebandnet/rain.wav' to 'evaluation_sounds_noisebandnet/rain/rain.wav'
# Creating folder 'evaluation_sounds_noisebandnet/rain_resynth'...
# Copied 'evaluation_sounds_noisebandnet/rain_resynth.wav' to 'evaluation_sounds_noisebandnet/rain_resynth/rain_resynth.wav'
# Evaluating texture type: river
# Creating folder 'evaluation_sounds_noisebandnet/river'...
# Copied 'evaluation_sounds_noisebandnet/river.wav' to 'evaluation_sounds_noisebandnet/river/river.wav'
# Creating folder 'evaluation_sounds_noisebandnet/river_resynth'...
# Copied 'evaluation_sounds_noisebandnet/river_resynth.wav' to 'evaluation_sounds_noisebandnet/river_resynth/river_resynth.wav'
# Evaluating texture type: shards
# Creating folder 'evaluation_sounds_noisebandnet/shards'...
# Copied 'evaluation_sounds_noisebandnet/shards.wav' to 'evaluation_sounds_noisebandnet/shards/shards.wav'
# Creating folder 'evaluation_sounds_noisebandnet/shards_resynth'...
# Copied 'evaluation_sounds_noisebandnet/shards_resynth.wav' to 'evaluation_sounds_noisebandnet/shards_resynth/shards_resynth.wav'
# Evaluating texture type: waterfall
# Creating folder 'evaluation_sounds_noisebandnet/waterfall'...
# Copied 'evaluation_sounds_noisebandnet/waterfall.wav' to 'evaluation_sounds_noisebandnet/waterfall/waterfall.wav'
# Creating folder 'evaluation_sounds_noisebandnet/waterfall_resynth'...
# Copied 'evaluation_sounds_noisebandnet/waterfall_resynth.wav' to 'evaluation_sounds_noisebandnet/waterfall_resynth/waterfall_resynth.wav'
# Evaluating texture type: wind
# Creating folder 'evaluation_sounds_noisebandnet/wind'...
# Copied 'evaluation_sounds_noisebandnet/wind.wav' to 'evaluation_sounds_noisebandnet/wind/wind.wav'
# Creating folder 'evaluation_sounds_noisebandnet/wind_resynth'...
# Copied 'evaluation_sounds_noisebandnet/wind_resynth.wav' to 'evaluation_sounds_noisebandnet/wind_resynth/wind_resynth.wav'
# Results for noisebandnet:
# evaluation_sounds_noisebandnet/bubbles_resynth.wav: 21.373807079526642
# evaluation_sounds_noisebandnet/fire_resynth.wav: 2.525980359319645
# evaluation_sounds_noisebandnet/keyboard_resynth.wav: 9.708295259729061
# evaluation_sounds_noisebandnet/rain_resynth.wav: 11.313814752679514
# evaluation_sounds_noisebandnet/river_resynth.wav: 49.85651251944835
# evaluation_sounds_noisebandnet/shards_resynth.wav: 1.3577502968673048
# evaluation_sounds_noisebandnet/waterfall_resynth.wav: 25.88299371777406
# evaluation_sounds_noisebandnet/wind_resynth.wav: 31.34695888133405

# %% [markdown]
# ### 3. TexStat and MSS frame-by-frame score

# %%
import sys
import os

# Add the parent directory to the Python path
parent_dir = os.path.abspath('texstat/')
if parent_dir not in sys.path:
    sys.path.append(parent_dir)
    
from texstat.segmentation import *
from texstat.functions import *
import torch
from texstat.fad import *
import texstat.torch_filterbanks.filterbanks as fb
import librosa
import torchaudio

# Multiscale Spectrogram Loss for comparison
def multiscale_fft(signal, scales=[4096, 2048, 1024, 512, 256, 128], overlap=.75):
    stfts = []
    for s in scales:
        S = torch.stft(
            signal,
            s,
            int(s * (1 - overlap)),
            s,
            torch.hann_window(s).to(signal),
            True,
            normalized=True,
            return_complex=True,
        ).abs()
        stfts.append(S)
    return stfts

def safe_log(x):
    return torch.log(x + 1e-7)

def multiscale_spectrogram_loss(x, x_hat):
    ori_stft = multiscale_fft(x)
    rec_stft = multiscale_fft(x_hat)
    loss = 0
    for s_x, s_y in zip(ori_stft, rec_stft):
        lin_loss = (s_x - s_y).abs().mean()
        log_loss = (safe_log(s_x) - safe_log(s_y)).abs().mean()
        loss = loss + lin_loss + log_loss
    return loss

# TexStat parameters
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
sr            = 44100
frame_size    = sr
N_filter_bank = 16
M_filter_bank = 6
N_moments     = 4
alpha         = torch.tensor([10, 1, 1/10, 1/100], device=device)
beta          = torch.tensor([1, 1, 1, 1, 1], device=device) 
new_sr, new_frame_size = sr // 4, frame_size // 4 # for downsampler
downsampler = torchaudio.transforms.Resample(sr, new_sr).to(device)
coch_fb     = fb.EqualRectangularBandwidth(frame_size, sr, N_filter_bank, 20, sr // 2)
mod_fb      = fb.Logarithmic(new_frame_size,       new_sr, M_filter_bank, 10, new_sr // 4)

# %%
# Evaluate using texStat and MSS on texDSP
for texture_type in texture_types:
    print("Texture type: ", texture_type)
    for pair in pairs_texDSP[texture_type]:
        print("Pair: ", pair)
        original_path         = pair[0]
        original_segments     = segment_audio(original_path, sr, sr, torch_type=True)
        reproduction_path     = pair[1]
        reproduction_segments = segment_audio(reproduction_path, sr, sr, torch_type=True)
        min_segments = min(len(original_segments), len(reproduction_segments))
        stats_loss = []
        mss_loss   = []
        for i in range(min_segments):
            og   = original_segments[i].to(device)
            fake = reproduction_segments[i].to(device)
            stats_loss_local = texstat_loss(og, fake, coch_fb, mod_fb, downsampler, N_moments, alpha, beta)
            mss_loss_local   = multiscale_spectrogram_loss(og, fake)
            stats_loss.append(stats_loss_local)  # Convert to scalar
            mss_loss.append(mss_loss_local)
        # torch stack
        stats_loss = torch.stack(stats_loss)
        mss_loss   = torch.stack(mss_loss)
        # Report mean and std
        stats_loss_mean = stats_loss.mean().item()
        stats_loss_std  = stats_loss.std().item()
        mss_loss_mean   = mss_loss.mean().item()
        mss_loss_std    = mss_loss.std().item()
        # Report
        print(f"Stats loss mean ± std: ${stats_loss_mean:.1f} \\pm {stats_loss_std:.1f}$")
        print(f"MSS loss mean ± std: ${mss_loss_mean:.1f} \\pm {mss_loss_std:.1f}$")
# Out:
# Texture type:  bubbles
# Pair:  ['evaluation_sounds_texDSP/bubbles.wav', 'evaluation_sounds_texDSP/bubbles_1.wav']
# Stats loss mean ± std: $1.3 \pm 0.3$
# MSS loss mean ± std: $7.9 \pm 0.7$
# Pair:  ['evaluation_sounds_texDSP/bubbles.wav', 'evaluation_sounds_texDSP/bubbles_2.wav']
# Stats loss mean ± std: $1.4 \pm 0.3$
# MSS loss mean ± std: $7.4 \pm 0.5$
# Pair:  ['evaluation_sounds_texDSP/bubbles.wav', 'evaluation_sounds_texDSP/bubbles_3.wav']
# Stats loss mean ± std: $1.2 \pm 0.3$
# MSS loss mean ± std: $6.6 \pm 0.3$
# Pair:  ['evaluation_sounds_texDSP/bubbles.wav', 'evaluation_sounds_texDSP/bubbles_4.wav']
# Stats loss mean ± std: $1.5 \pm 0.3$
# MSS loss mean ± std: $8.1 \pm 0.5$
# Texture type:  fire
# Pair:  ['evaluation_sounds_texDSP/fire.wav', 'evaluation_sounds_texDSP/fire_1.wav']
# Stats loss mean ± std: $2.9 \pm 2.0$
# MSS loss mean ± std: $10.1 \pm 1.2$
# Pair:  ['evaluation_sounds_texDSP/fire.wav', 'evaluation_sounds_texDSP/fire_2.wav']
# Stats loss mean ± std: $2.9 \pm 2.1$
# MSS loss mean ± std: $9.6 \pm 1.3$
# Pair:  ['evaluation_sounds_texDSP/fire.wav', 'evaluation_sounds_texDSP/fire_3.wav']
# Stats loss mean ± std: $2.8 \pm 2.2$
# MSS loss mean ± std: $10.3 \pm 1.5$
# Pair:  ['evaluation_sounds_texDSP/fire.wav', 'evaluation_sounds_texDSP/fire_4.wav']
# Stats loss mean ± std: $2.8 \pm 2.2$
# MSS loss mean ± std: $10.4 \pm 1.6$
# Pair:  ['evaluation_sounds_texDSP/fire.wav', 'evaluation_sounds_texDSP/fire_5.wav']
# Stats loss mean ± std: $3.4 \pm 2.6$
# MSS loss mean ± std: $12.7 \pm 2.4$
# Texture type:  keyboard
# Pair:  ['evaluation_sounds_texDSP/keyboard.wav', 'evaluation_sounds_texDSP/keyboard_1.wav']
# Stats loss mean ± std: $5.7 \pm 2.0$
# MSS loss mean ± std: $9.1 \pm 0.7$
# Texture type:  rain
# Pair:  ['evaluation_sounds_texDSP/rain.wav', 'evaluation_sounds_texDSP/rain_1.wav']
# Stats loss mean ± std: $0.5 \pm 0.2$
# MSS loss mean ± std: $9.5 \pm 0.3$
# Pair:  ['evaluation_sounds_texDSP/rain.wav', 'evaluation_sounds_texDSP/rain_2.wav']
# Stats loss mean ± std: $0.5 \pm 0.2$
# MSS loss mean ± std: $9.0 \pm 0.2$
# Texture type:  river
# Pair:  ['evaluation_sounds_texDSP/river.wav', 'evaluation_sounds_texDSP/river_1.wav']
# Stats loss mean ± std: $0.5 \pm 0.1$
# MSS loss mean ± std: $7.7 \pm 0.8$
# Pair:  ['evaluation_sounds_texDSP/river.wav', 'evaluation_sounds_texDSP/river_2.wav']
# Stats loss mean ± std: $0.5 \pm 0.1$
# MSS loss mean ± std: $6.5 \pm 0.7$
# Pair:  ['evaluation_sounds_texDSP/river.wav', 'evaluation_sounds_texDSP/river_3.wav']
# Stats loss mean ± std: $0.5 \pm 0.1$
# MSS loss mean ± std: $6.0 \pm 0.6$
# Texture type:  shards
# Pair:  ['evaluation_sounds_texDSP/shards.wav', 'evaluation_sounds_texDSP/shards_1.wav']
# Stats loss mean ± std: $1.0 \pm 0.2$
# MSS loss mean ± std: $7.9 \pm 0.2$
# Texture type:  waterfall
# Pair:  ['evaluation_sounds_texDSP/waterfall.wav', 'evaluation_sounds_texDSP/waterfall_1.wav']
# Stats loss mean ± std: $0.3 \pm 0.0$
# MSS loss mean ± std: $5.0 \pm 0.0$
# Pair:  ['evaluation_sounds_texDSP/waterfall.wav', 'evaluation_sounds_texDSP/waterfall_2.wav']
# Stats loss mean ± std: $0.3 \pm 0.0$
# MSS loss mean ± std: $5.0 \pm 0.0$
# Texture type:  wind
# Pair:  ['evaluation_sounds_texDSP/wind.wav', 'evaluation_sounds_texDSP/wind_1.wav']
# Stats loss mean ± std: $0.8 \pm 0.5$
# MSS loss mean ± std: $5.6 \pm 0.1$
# Pair:  ['evaluation_sounds_texDSP/wind.wav', 'evaluation_sounds_texDSP/wind_2.wav']
# Stats loss mean ± std: $0.8 \pm 0.6$
# MSS loss mean ± std: $5.5 \pm 0.1$

# %%
# Evaluate using texStat and MSS on noisebandnet
for texture_type in texture_types:
    print("Texture type: ", texture_type)
    for pair in pairs_noisebandnet[texture_type]:
        print("Pair: ", pair)
        original_path         = pair[0]
        original_segments     = segment_audio(original_path, sr, sr, torch_type=True)
        reproduction_path     = pair[1]
        reproduction_segments = segment_audio(reproduction_path, sr, sr, torch_type=True)
        min_segments = min(len(original_segments), len(reproduction_segments))
        stats_loss = []
        mss_loss   = []
        for i in range(min_segments):
            og   = original_segments[i].to(device)
            fake = reproduction_segments[i].to(device)
            stats_loss_local = texstat_loss(og, fake, coch_fb, mod_fb, downsampler, N_moments, alpha, beta)
            mss_loss_local   = multiscale_spectrogram_loss(og, fake)
            stats_loss.append(stats_loss_local)  # Convert to scalar
            mss_loss.append(mss_loss_local)
        # torch stack
        stats_loss = torch.stack(stats_loss)
        mss_loss   = torch.stack(mss_loss)
        # Report mean and std
        stats_loss_mean = stats_loss.mean().item()
        stats_loss_std  = stats_loss.std().item()
        mss_loss_mean   = mss_loss.mean().item()
        mss_loss_std    = mss_loss.std().item()
        # Report
        print(f"Stats loss mean ± std: ${stats_loss_mean:.1f} \\pm {stats_loss_std:.1f}$")
        print(f"MSS loss mean ± std: ${mss_loss_mean:.1f} \\pm {mss_loss_std:.1f}$")
# Out:
# Texture type:  bubbles
# Pair:  ['evaluation_sounds_noisebandnet/bubbles.wav', 'evaluation_sounds_noisebandnet/bubbles_resynth.wav']
# Stats loss mean ± std: $0.7 \pm 0.1$
# MSS loss mean ± std: $4.7 \pm 0.1$
# Texture type:  fire
# Pair:  ['evaluation_sounds_noisebandnet/fire.wav', 'evaluation_sounds_noisebandnet/fire_resynth.wav']
# Stats loss mean ± std: $1.7 \pm 1.0$
# MSS loss mean ± std: $4.5 \pm 0.2$
# Texture type:  keyboard
# Pair:  ['evaluation_sounds_noisebandnet/keyboard.wav', 'evaluation_sounds_noisebandnet/keyboard_resynth.wav']
# Stats loss mean ± std: $20.0 \pm 7.7$
# MSS loss mean ± std: $13.8 \pm 0.6$
# Texture type:  rain
# Pair:  ['evaluation_sounds_noisebandnet/rain.wav', 'evaluation_sounds_noisebandnet/rain_resynth.wav']
# Stats loss mean ± std: $2.4 \pm 2.0$
# MSS loss mean ± std: $9.1 \pm 0.4$
# Texture type:  river
# Pair:  ['evaluation_sounds_noisebandnet/river.wav', 'evaluation_sounds_noisebandnet/river_resynth.wav']
# Stats loss mean ± std: $0.6 \pm 0.1$
# MSS loss mean ± std: $6.7 \pm 0.3$
# Texture type:  shards
# Pair:  ['evaluation_sounds_noisebandnet/shards.wav', 'evaluation_sounds_noisebandnet/shards_resynth.wav']
# Stats loss mean ± std: $1.1 \pm 0.3$
# MSS loss mean ± std: $8.8 \pm 0.2$
# Texture type:  waterfall
# Pair:  ['evaluation_sounds_noisebandnet/waterfall.wav', 'evaluation_sounds_noisebandnet/waterfall_resynth.wav']
# Stats loss mean ± std: $0.4 \pm 0.0$
# MSS loss mean ± std: $6.3 \pm 0.0$
# Texture type:  wind
# Pair:  ['evaluation_sounds_noisebandnet/wind.wav', 'evaluation_sounds_noisebandnet/wind_resynth.wav']
# Stats loss mean ± std: $1.1 \pm 0.7$
# MSS loss mean ± std: $5.8 \pm 0.2$
