# %%
import sys
import os

# Add the parent directory to the Python path
parent_dir = os.path.abspath('../..')
if parent_dir not in sys.path:
    sys.path.append(parent_dir)

# import modules
import ddsp_textures.training.wrapper

# %%
# Testing the trainer
json_path = 'config_template_TexEnv.json'

# Run the training
ddsp_textures.training.wrapper.train(json_path)
# Out:
# DDSP_TexEnv trainer
# ['energy_bands', 'freqavg']
# []
# Model Parameters:
#
# features: [<function features_energy_bands at 0x70b4cc78d440>, <function features_freqavg at 0x70b4cc78d260>]
# regularizers: []
# input_dimensions: [16, 1]
# audio_path: ../sounds/mini_dataset_example
# frame_size: 32768
# hop_size: 16384
# sampling_rate: 44100
# hidden_size_enc: 256
# hidden_size_dec: 256
# deepness_enc: 3
# deepness_dec: 3
# param_per_env: 256
# N_filter_bank: 16
# M_filter_bank: 6
# architecture: <class 'ddsp_textures.architectures.DDSP.DDSP_TexEnv'>
# stems: False
# loss_function: <function batch_statistics_loss at 0x70b4cc78e200>
# batch_size: 32
# epochs: 10
# models_directory: ../trained_models
# model id: model_48
#
# Audio loaded from  ../sounds/mini_dataset_example
# Computing dataset
# ...
# /home/esteban/projects/ddsp_textures/ddsp_textures/auxiliar/features.py:134: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(mean_frequency)
# Dataset computed!
# Creating encoder with input size 16
# Creating encoder with input size 1
# Training starting!
# number_of_features 2
# num_of_regularizers 0
# Epoch 1/10: 100%|██████████| 7/7 [00:27<00:00,  3.95s/it]
# Epoch [1/10], Loss: 1413.2389, Main Loss: 1413.2389, Regularizer: 0.0000
# Epoch 2/10: 100%|██████████| 7/7 [00:27<00:00,  3.96s/it]
# Epoch [2/10], Loss: 149.8560, Main Loss: 149.8560, Regularizer: 0.0000
# Epoch 3/10: 100%|██████████| 7/7 [00:27<00:00,  3.97s/it]
# Epoch [3/10], Loss: 25.1341, Main Loss: 25.1341, Regularizer: 0.0000
# Epoch 4/10: 100%|██████████| 7/7 [00:27<00:00,  3.99s/it]
# Epoch [4/10], Loss: 11.4607, Main Loss: 11.4607, Regularizer: 0.0000
# Epoch 5/10: 100%|██████████| 7/7 [00:27<00:00,  3.97s/it]
# Epoch [5/10], Loss: 9.6539, Main Loss: 9.6539, Regularizer: 0.0000
# Epoch 6/10: 100%|██████████| 7/7 [00:27<00:00,  3.97s/it]
# Epoch [6/10], Loss: 9.6263, Main Loss: 9.6263, Regularizer: 0.0000
# Epoch 7/10: 100%|██████████| 7/7 [00:27<00:00,  3.98s/it]
# Epoch [7/10], Loss: 10.3598, Main Loss: 10.3598, Regularizer: 0.0000
# Epoch 8/10: 100%|██████████| 7/7 [00:28<00:00,  4.08s/it]
# Epoch [8/10], Loss: 10.1900, Main Loss: 10.1900, Regularizer: 0.0000
# Epoch 9/10: 100%|██████████| 7/7 [00:28<00:00,  4.07s/it]
# Epoch [9/10], Loss: 9.4699, Main Loss: 9.4699, Regularizer: 0.0000
# Epoch 10/10: 100%|██████████| 7/7 [00:28<00:00,  4.03s/it]
# Epoch [10/10], Loss: 9.2980, Main Loss: 9.2980, Regularizer: 0.0000
# Training complete.
