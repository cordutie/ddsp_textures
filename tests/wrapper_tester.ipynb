# %%
import sys
import os

# Add the parent directory to the Python path
parent_dir = os.path.abspath('../..')
if parent_dir not in sys.path:
    sys.path.append(parent_dir)

# import modules
import ddsp_textures.training.wrapper

# %%
# Testing the trainer
json_path = '../auxiliar/config_template_subenv.json'

# Run the training
ddsp_textures.training.wrapper.train(json_path)
# Out:
# Model Parameters:
#
# audio_path: ../sounds/fire_short.wav
# frame_size: 32768
# hop_size: 16384
# sampling_rate: 44100
# features_annotator: <function features_freqavg_rate at 0x78b50915ab00>
# batch_features_annotator: <function batch_features_freqavg_rate at 0x78b50915ac20>
# freq_avg_level: 4
# hidden_size: 512
# deepness: 3
# param_per_env: 512
# N_filter_bank: 16
# architecture: <class 'ddsp_textures.architectures.DDSP.DDSP_TextEnv'>
# onset_detection_model_path: none
# loss_function: <function batch_statistics_loss at 0x78b50915b490>
# regularization: True
# batch_size: 16
# epochs: 2
# directory: ../trained_models
# VAE_model_directory: ../architectures/pre_trained_models/VAE_water/
# VAE_latent_dim: 2
# VAE_atoms_size: 16384
# atoms_number: 4
# model id: model_19
# ...

# %%
# Testing the trainer
json_path = '../auxiliar/config_template_pvae.json'

# Run the training
ddsp_textures.training.wrapper.train(json_path)
# Out:
# DDSP_PVAE trainer
# Model Parameters:
#
# audio_path: ../sounds/water_short.wav
# frame_size: 65536
# hop_size: 65536
# sampling_rate: 44100
# features_annotator: <function features_freqavg_freqstd at 0x7985b415ec20>
# batch_features_annotator: <function batch_features_freqavg_freqstd at 0x7985b415ed40>
# freq_avg_level: 4
# hidden_size: 256
# deepness: 2
# param_per_env: 512
# N_filter_bank: 16
# architecture: <class 'ddsp_textures.architectures.DDSP.DDSP_PVAE'>
# onset_detection_model_path: none
# loss_function: <function batch_statistics_loss at 0x7985b415f640>
# regularization: False
# batch_size: 2
# epochs: 2
# directory: ../trained_models
# VAE_model_directory: ../architectures/pre_trained_models/VAE_water/
# VAE_latent_dim: 2
# VAE_atoms_size: 16384
# atoms_number: 4
# ...
