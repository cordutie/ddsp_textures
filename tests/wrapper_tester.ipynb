# %%
import sys
import os

# Add the parent directory to the Python path
parent_dir = os.path.abspath('../..')
if parent_dir not in sys.path:
    sys.path.append(parent_dir)

# import modules
import ddsp_textures.training.wrapper

# %%
# Testing the trainer
json_path = 'config_template_subenv.json'

# Run the training
ddsp_textures.training.wrapper.train(json_path)
# Out:
# DDSP_SubEnv trainer
# ['energy_bands', 'rate']
# []
# Model Parameters:
#
# features: [<function features_energy_bands at 0x7c2cb6ee5440>, <function features_rate at 0x7c2cb6ee53a0>]
# regularizers: []
# input_dimensions: [24, 1]
# audio_path: ../sounds/mini_dataset_example
# frame_size: 32768
# hop_size: 16384
# sampling_rate: 44100
# hidden_size_enc: 512
# hidden_size_dec: 512
# deepness_enc: 3
# deepness_dec: 3
# param_per_env: 1024
# N_filter_bank: 24
# M_filter_bank: 12
# architecture: <class 'ddsp_textures.architectures.DDSP.DDSP_SubEnv'>
# stems: True
# loss_function: <function batch_statistics_loss_stems at 0x7c2cb6ee6340>
# batch_size: 32
# epochs: 10
# models_directory: ../trained_models
# model id: model_17
#
# Audio loaded from  ../sounds/mini_dataset_example
# Computing dataset
# ...
# /home/esteban/projects/ddsp_textures/auxiliar/features.py:163: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(rate)
# Dataset computed!
# Creating encoder with input size 24
# Creating encoder with input size 1
# Training starting!
# number_of_features 2
# num_of_regularizers 0
# Epoch 1/10: 100%|██████████| 13/13 [04:02<00:00, 18.68s/it]
# Epoch [1/10], Loss: 504.7194, Main Loss: 504.7194, Regularizer: 0.0000
# Epoch 2/10: 100%|██████████| 13/13 [04:07<00:00, 19.00s/it]
# Epoch [2/10], Loss: 1.3700, Main Loss: 1.3700, Regularizer: 0.0000
# Epoch 3/10: 100%|██████████| 13/13 [04:11<00:00, 19.32s/it]
# Epoch [3/10], Loss: 1.3436, Main Loss: 1.3436, Regularizer: 0.0000
# Epoch 4/10: 100%|██████████| 13/13 [04:10<00:00, 19.30s/it]
# Epoch [4/10], Loss: 1.3299, Main Loss: 1.3299, Regularizer: 0.0000
# Epoch 5/10: 100%|██████████| 13/13 [04:13<00:00, 19.46s/it]
# Epoch [5/10], Loss: 1.3253, Main Loss: 1.3253, Regularizer: 0.0000
# Epoch 6/10: 100%|██████████| 13/13 [04:10<00:00, 19.26s/it]
# Epoch [6/10], Loss: 1.3256, Main Loss: 1.3256, Regularizer: 0.0000
# Epoch 7/10: 100%|██████████| 13/13 [04:11<00:00, 19.33s/it]
# Epoch [7/10], Loss: 1.3084, Main Loss: 1.3084, Regularizer: 0.0000
# Epoch 8/10: 100%|██████████| 13/13 [04:13<00:00, 19.51s/it]
# Epoch [8/10], Loss: 1.3243, Main Loss: 1.3243, Regularizer: 0.0000
# Epoch 9/10: 100%|██████████| 13/13 [04:19<00:00, 19.94s/it]
# Epoch [9/10], Loss: 1.3043, Main Loss: 1.3043, Regularizer: 0.0000
# Epoch 10/10: 100%|██████████| 13/13 [04:22<00:00, 20.21s/it]
# Epoch [10/10], Loss: 1.3100, Main Loss: 1.3100, Regularizer: 0.0000
# Training complete.
